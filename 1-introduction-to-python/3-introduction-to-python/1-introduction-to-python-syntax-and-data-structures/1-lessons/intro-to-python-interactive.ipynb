# %% [markdown]
# # Introduction to Python syntax and data structures
# - Python is an open source general-purpose coding language, it was created by Guido van Rossum and first released in 1991
# - Python is a beginner-friendly language, python code syntax uses English keywords, that makes it easy for anyone to understand and get started with the language

# %% [markdown]
# **What we cover:**
#
# **Part 1 - Introduction to Python**
# - Basic Data Types
#     - integers (int)
#     - floats (float)
#     - strings (str)
#     - booleans (bool)
#
# - Variables
# - Arithmetic Operators
# - Comments
# - String Indexing
# - Data Type Conversions
# - String Formatting
#
#
# **Part 2 - Python Data structures**
# - Python Data Structures
#     - Lists
#     - Dictionaries
#     - Tuples
#     - Sets
#
# - Combining Data Structures

# %% [markdown]
# # Part 1 - Introduction to Python

# %% [markdown]
# ## ☑️ Basic Data Types

# %% [markdown]
# Python has the following four basic data types:
# <img src="data:image/png;base64,..."  alt="basic data types" width="600" height="400">

# %% [markdown]
# | Data type | Description   |
# |:- |:- |
# |**integers** (`int`)	|whole numbers, such as `42`, `3`, `56409`|
# |**floats** (`float`)	|decimal numbers, such as `57.346`, `0.2`, `5.0`|
# |**strings** (`str`) 	|sequences of characters, such as `Hello, World.`, `'I\'m 37'`|
# |**booleans** (`bool`)	|can only be either `True` or `False`|

# %% [markdown]
# ## ☑️ Variables

# %% [markdown]
# - A **variable** is simply a name for something that we need to remember
# - We can **assign values** to **variables**, which are stored in the computer's memory(RAM)
# - Assignment operator `=` needs to be used while creating a variable

# %% [markdown]
# Rules for Python variables:
# - Variable names cannot have spaces in them (normally **\_underscore\_** is used instead of space)
# - Variable names can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# - Variable names are case-sensitive
# - Variable names cannot start with a number

# %%
age = 25
weight_in_kg = 61.4
name = 'Mary'
is_male = False

# %% [markdown]
# Python can automatically  determine data type of any object by using the `type()` function

# %%
type(weight_in_kg)

# %% [markdown]
# #### Question
# Find the type of `is_male` variable

# %%
#add your code here

# %% [markdown]
# ## ☑️ Arithmetic Operators

# %% [markdown]
# - Arithmetic operators are used with numeric values to perform common mathematical operations
# - Python abides by BODMAS rules, so brackets first, orders/exponents, division/multiplication, addition/subtraction
# - More info can be found [here](https://www.twinkl.co.uk/teaching-wiki/bodmas)

# %% [markdown]
# | Operator | Description   |
# |:- |:- |
# |+	|Addition|
# |-	|Subtraction|
# |*	|Multiplication|
# |**	|Exponentiation|
# |/	|Division|
# |//	|Floor division|
# |%	|Modulus|

# %% [markdown]
# #### Addition and subtraction

# %%
(4 + 4) - 2

# %%
1 - 3 + 0.5

# %% [markdown]
# `int` and `float` values can be used concurrently.

# %% [markdown]
# #### Multiplication

# %%
4 * 2 * 2.5

# %%
3 ** 3

# %% [markdown]
# `**` is used for **exponentiation** (*'to the power of'*)

# %% [markdown]
# #### Question
# Suppose you have £50, which you want to invest with a 20% return each year, for 8 years.
#
# - After 1  year  --> 50 × 1.2       = 60
# - After 2 years --> 50 × 1.2 × 1.2 = 72
# - After 3 years --> 50 × 1.2 × 1.2 × 1.2 = 86.4
# - .....
# - .....
#
# Add code below to calculate how much money you end up having after 8 years?

# %%
#add your code here

# %% [markdown]
# #### Division

# %%
365 / 7

# %% [markdown]
# Division using `/` always results in a value of type `float`.

# %% [markdown]
# #### Other types of division
#
# * Floor division, using `//`
# * Modulo using `%`

# %%
365 // 7

# %% [markdown]
# - Floor division operator `//` divides the number, and then rounds down the nearest integer.

# %%
365 % 7

# %% [markdown]
# - The modulo operator `%` divides number, and gives you the remainder as the result

# %% [markdown]
# #### Question
# You have been tasked with packaging items. You have been given 7 items. Each package should hold exactly 3 items. How many packages with 3 items would you be able to make?

# %%
#add your code here

# %% [markdown]
# #### String manipulation using Arithmetic operators
#
# - These operators can sometimes be used on strings:

# %%
5 * 'Democracy'

# %% [markdown]
# - Multiplication operator when used with the string it creates copies of the same string.

# %%
'London' + ' ' + 'UK'

# %% [markdown]
# - String concatenation using Addition operator

# %%
'Democracy' / 5

# %% [markdown]
# … but sometimes not possible with other operators

# %% [markdown]
# #### Using Arithmetic operators with variables

# %%
items = 250
defects = 6
item_price = 5
total_cost = 1000

# %% [markdown]
# - Assignment operator `=` needs to be used while creating variables

# %%
defect_rate = (defects/items) * 100
defect_rate

# %%
revenue = item_price * (items - defects)
revenue

# %%
profit = revenue - total_cost
profit

# %% [markdown]
# ### **Various assignment operators**

# %% [markdown]
# When performing certain operations on a single variable, we can use the following more succinct syntax:

# %% [markdown]
# | Operator | Description   | Result|
# |:- |:- |:- |
# |=	|x = 10	|x = 10|
# |+=	|x += 10	|x = x + 10|
# |-=	|x -= 10	|x = x - 10|
# |*= |x *= 10	|x = x * 10|

# %%
attendance = 100
attendance = attendance + 3
attendance

# %%
attendance = 100
attendance += 3 #equivalent to attendance = attendance + 3
attendance

# %% [markdown]
# #### Question
#
# \begin{equation*} BMI =
# \frac{weight (kg)}{height^{2} (m^{2})} \end{equation*}
#
# Calculate **Body Mass Index** for James, save the results into a variable called **bmi**

# %%
name = "James"   
age = 25         
height = 1.8     # height in meters
weight = 75      # weight in kg

print(name)
print(age)
print(height)
print(weight)

# %%
#add your code below

# %% [markdown]
# ## ☑️ Comments

# %% [markdown]
# - Comments can be used to explain Python code and make the code more readable
# - We can add **comments** to our code in the following ways:

# %%
'''
Code for calculation of revenue.
Assumes no failed payments or price changes.
'''

attendance = 100
ticket_price = 10

revenue = attendance * ticket_price #assuming refunds are paid in full
revenue

# %% [markdown]
# - **Multi-line comments** sit within `'''`three speech marks`'''`
# - **Single line comments** (which can share a line with working code) sit to the right of a `#` character

# %% [markdown]
# ## ☑️ String Indexing
#
# - It means accessing a specific part of the string, usings its index.
# - In Python **the index starts at zero**. This means that when you want to access the **first** letter in a string, you actually mean the **zeroth** index
# - Indexing is a teachnique used in many programming languages.

# %% [markdown]
# <img src="data:image/png;base64,..."  alt="string index" width="600" height="400">

# %% [markdown]
# We can access an individual character, or series of characters of a `string` by providing numerical values (**indexes**) within **`[`square brackets`]`**.
#
# Syntax for accessing elements is:
# - `[position]`
# - `[start:stop]`
# - `[start:stop:step]`

# %%
name = 'Alison Bell'
name

# %%
len(name)

# %% [markdown]
# - The built-in `len()` function can be used on lists and strings to determine their **length**: Including spaces

# %%
name[0]

# %%
name[2]

# %% [markdown]
# - If a **single value** is provided, the character at that specific index is accessed

# %%
name[0:5]

# %%
name[7:10]

# %% [markdown]
# If a **pair of values separated by a `:`** are provided, these are interpreted as `start` and `stop` values.
#
# - Note how the character at the `stop` position is **not included**
# - The **difference** in values will be the **number of characters** returned

# %%
name[:3]

# %%
name[1:]

# %%
name[:]

# %% [markdown]
# - Use of a **`:` without values on one or both sides** is interpreted as there being **no limit in the given direction(s)**.

# %%
name[0:5:2]

# %%
name[::2]

# %% [markdown]
# - If **two colons** are used, any value to the right of the second colon is interpreted as the `step` value.

# %% [markdown]
# <img src="data:image/png;base64,..."  alt="string index" width="600" height="400">

# %% [markdown]
# **Negative values** can be used to refer to a position in relation to the **end** of the string.
#
# - The `[position]`, `[start:stop]`, and `[start:stop:step]` structures continue to work in the same way.

# %%
name = 'Alison Bell'

name[-3]

# %%
name[:-3]

# %%
name[-3:]

# %%
name[::-1]

# %% [markdown]
# - To reverse an order of a string keep the start and stop positions empty, and use -1 as the step size

# %% [markdown]
# ### Type conversion (casting)

# %% [markdown]
# Attempting operations with values of the wrong data type can result in errors:

# %%
meals = '4.99'
meals = meals + 1
meals

# %% [markdown]
# There are several **built-in functions** we can use to convert the **type** of a value where possible, each corresponding to the **data types** we saw earlier. This is also referred to as **casting**, following are some common casting functions in Python:
#
# | Function | Description   |
# |:- |:- |
# |   **str()**  | Returns the string version of the object|
# |   **int()**  | Returns integer from a number or string|
# |   **float()**  | Returns floating point number from number, string|
# |   **bool()**  | Converts a data value to Boolean|

# %%
meals = '4.99'
meals = float(meals)
meals = meals + 1
meals

# %%
int(meals)

# %% [markdown]
# Note that conversion of a `float` to an `int` using built-in function `int()` simply **truncates** the value rather than rounding it:
#
# In this instance, we might instead want to use another built-in function `round()`

# %%
round(meals,0) # The zero here sets the number of decimal places

# %% [markdown]
# ## ☑️ String Formatting

# %% [markdown]
# - Python knows that something is a `string` when you put it within either `"` or `'` quotation marks.
# - Use `print()` function to print a specific message to the screen
#
# Rules for Python String formatting:
# - The **same type of quotation mark** must be used at the **start** and **finish**
# - The type of quotation mark not used at the ends can be used *within* the string

# %%
"Samantha said, 'I'm 30 years old today!'"

# %%
print("Samantha said, 'I'm 30 years old today!'")

# %% [markdown]
# `f-strings` provide a way to embed `variables` inside a `string`:

# %%
name = 'Paul'
age = 40

# %%
f"{name} said, I'm {age} years old today!"

# %%
print(f"{name} said, 'I'm {age} years old today!'")

# %% [markdown]
# - We have put an `f` before the string and the required variables within `{`braces`}`

# %% [markdown]
# You may also use `format()` method to insert `variables` into a `string`:

# %%
"{} said, 'I'm {} years old today!'".format(name, age)

# %%
print("{} said, 'I'm {} years old today!'".format(name, age))

# %% [markdown]
# The `f-strings` functionality we saw previously is more concise, but was only introduced in Python 3.6 (December 2016).
#
# The older `.format()` method continues to be supported.

# %% [markdown]
# <img src="data:image/png;base64,..."  width="200">
#
#
# Now open the following workbook: `intro-python-syntax-workbook.ipynb`

# %% [markdown]
# # Part 2 - Python Data structures

# %% [markdown]
# <img src="data:image/png;base64,..."  alt="python data structures" width="600" height="400">

# %% [markdown]
# Now it's time to take a closer look at four **built-in data structures** in Python. Each one is associated with a type of brackets:
# (A lot of what you have learned so far is recyclable here!)
#
# | Name | Description   | Brackets   |
# |:- |:- |:- |
# |   **lists**  | an editable(mutable), **ordered collection** of values |Associated with square brackets `[]`|
# |   **dictionaries**  | an unordered, editable collection of **`key:value` pairs** |Associated with curly brackets `{}`|
# |   **tuples**  | similar to lists, but **not editable**(immutable) |Associated with round brackets `()`|
# |   **sets**  | an unordered, editable collection **unique values**|Associated with curly brackets `{}`|

# %% [markdown]
# - Data structures are used to **store** and **organise** data
#
# - You are likely to encounter **lists** and **dictionaries** more frequently than **tuples** and **sets**
#
# - You will use other, more **specialised data structures** in future when using **packages** such as **pandas**

# %% [markdown]
# ## ☑️ Lists
# In Python a list is created by placing all the elements inside **square brackets [ ]**, separated by commas
#
# - Lists have  a variable number of elements
# - Elements can be **added**, **removed** or **modified**
# - Elements are accessed using a **zero-based index**
# - Elements do not have to be the same data type
# - You can also define an empty list with square brackets, e.g. `my_list = []`
# - You can also create a list using the built-in `list()` function

# %% [markdown]
# #### List indexing

# %% [markdown]
# The syntax we can use for **accessing list elements by position** are the same as we have seen previously for strings, with the number of **numerical values** and **colons** determining the interpretation:
#
# - `[position]`
# - `[start:stop]`
# - `[start:stop:step]`
#
# Again, indexing is **zero-based**, and **negative values** can be used to access by **position from the end of the list**.

# %% [markdown]
# <img src="data:image/png;base64,..."  alt="python list index" width="600" height="400">

# %% [markdown]
# #### Define a list using square brackets `[]`

# %%
rain = [6.5, 0, 0, 1.2, 2.6, 5.4]

# %%
rain

# %%
type(rain)

# %%
len(rain)

# %% [markdown]
# - The built-in `len()` function can be used on lists and strings to determine their **length**

# %% [markdown]
# #### List indexing
# - Retrieving  items from the list, using indexing (remember that Python is zero indexed)

# %%
rain[4]

# %%
rain[1:4]

# %%
rain[4:]

# %%
rain[:4]

# %% [markdown]
# #### List indexing with negative values

# %%
rain[-2]

# %%
rain[-2:]

# %%
rain[:-2]

# %% [markdown]
# #### List indexing with step values

# %%
rain[::2]

# %%
rain[::-2]

# %%
rain[::-1]    #We can use negative values for `step` to return values in **reverse order**

# %% [markdown]
# #### Define a list using square brackets `[]`

# %%
people = ['Anna', 'Ben', 'Cynthia', 'Dennis', 'Evandro', 'Farhad']

# %%
people

# %%
type(people)

# %%
len(people)

# %% [markdown]
# #### Python List Methods
#
# - Python has a set of built-in methods that are available with every list object
#
# | Method | Description   |
# |:- |:- |
# |   append()  | Adds an item to the end of the list|
# |   clear()  | Removes all items from the list|
# |   copy()  | creates a new copy of the current list|
# |   count()  | Returns the count of the number of items passed as an argument|
# |   extend()  | Add all items of a list to the end of another list|
# |   index()  | Returns the index of the first item with the specified value|
# |   insert()  | Adds an item at the specified index position|
# |   pop()  | Removes an item from the list at the given index|
# |   remove()  | Removes the item with the specified value|
# |   reverse()  | Reverses the order of the list|
# |   sort()  | Sorts the list|

# %% [markdown]
# #### Some useful references:
# [Python List Methods](https://docs.python.org/3/tutorial/datastructures.html)
#
# [Python List Methods](https://www.w3schools.com/python/python_ref_list.asp)

# %% [markdown]
# #### Define a list using square brackets `[]`

# %%
scores = [10, 25, 14]
scores

# %%
scores

# %%
scores[0] = 50
scores

# %% [markdown]
# - Update the value at `index` `0` in the list

# %%
scores.append('Unknown')
scores

# %% [markdown]
# - Use `.append()` method to **add a single item** to a list

# %%
scores.pop()

# %%
scores

# %% [markdown]
# - `.pop()` returns the **last item** in the list, and **removes it** from the list

# %% [markdown]
# #### Define a list using square brackets `[]`

# %%
more_scores = [77, 33, 12]
more_scores

# %%
scores.extend(more_scores)

# %%
scores

# %% [markdown]
# `.extend()` allows us to **extend** a list with values from another list

# %%
scores.reverse()
scores

# %%
scores.sort(reverse=True)
scores

# %%
people.sort(reverse=True)
people

# %% [markdown]
# - `.reverse()` and `.sort()` work as expected
# - Using `.sort()` on a list of **strings** will sort them **alphabetically**

# %%
scores2 = scores.copy()
scores2.append(500)
scores2

# %% [markdown]
# - Creates a new copy of the current list using `.copy()` method

# %%
sorted(scores, reverse=True)

# %% [markdown]
# - The `sorted()` function returns a sorted list, similar to `.sort()` method

# %% [markdown]
# ## ☑️  Dictionaries
# You can define a dictionary by using curly brackets `{key:value}`, with each key and value separated by a colon `:`
#
# - Dictionaries **map values to keys** `{key:value}`
# - Each item stored in a dictionary is actually a **key:value pair**
# - Values are **accessed using the key** (rather than index)
# - Values can be modified and further **key:value pairs** added
# - You can also define an empty dictionary with curly brackets, e.g. `my_dict = {}`
# - You can also create a dictionary using the built-in `dict()` function

# %% [markdown]
# <img src="data:image/png;base64,..."  alt="python dict" width="600" height="400">

# %% [markdown]
# #### Define a dictionary using curly brackets `{key:value}`

# %%
user = {'Name': 'David',
        'Occupation': 'Magician',
        'Phone': 5554267,
        'Town': 'New York',
       }

# %%
user

# %%
type(user)

# %%
len(user)

# %% [markdown]
# We can use `keys` inside square brackets `[ ]` to **retrieve** `values`

# %%
user['Town']

# %%
user['Phone']

# %% [markdown]
# We can **add** or **modify** values in the same way as we would assign or update variables:

# %%
user['Town'] = 'San Francisco'    #modify
user['Gender'] = 'Male'           #add

# %%
user

# %% [markdown]
# #### Python Dictionary Methods
# - Python has a set of built-in methods that are available with every dictionary object
#
# | Method | Description   |
# |:- |:- |
# |copy()| creates a copy of the current dictionary|
# |get()|Returns the value of the specified key|
# |items()|Returns a list containing a tuple for each key-value pair|
# |keys()|Returns a list containing dictionary keys|
# |pop()|Removes items with the specified key|
# |update()|Updates the dictionary with the specified `{key:value}` pairs|
# |values()|Returns a list of all the values in the dictionary|

# %% [markdown]
# #### Some useful references:
#
# [Python Dictionary Methods](https://docs.python.org/3/tutorial/datastructures.html#dictionaries)
#
# [Python Dictionary Methods](https://www.w3schools.com/python/python_dictionaries_methods.asp)

# %%
user

# %%
user.update({'Town': 'Washington',
             'Country': 'USA'})
user

# %% [markdown]
# - `.update()` allows us to **update** an existing dictionary using another dictionary of `key:value` pairs

# %%
user['Age']

# %%
user.get('Age', 'Not provided')

# %% [markdown]
#  - `.get()` allows us to provide a **fallback value** should the given key not be found in the dictionary

# %%
user.keys()

# %%
user.values()

# %% [markdown]
# `.keys()` and `.values()` return a *view* of the **keys** and **values** respectively; we can use the **built-in `list()` function** to return the list itself from each:

# %%
list(user.keys())

# %%
list(user.values())

# %% [markdown]
# ## ☑️ Tuples
#
# In Python a tuple is created by placing all the elements inside **round brackets ( )**, separated by commas
#
# - Tuples contain an **ordered collection** of elements
# - The **number** of elements are **fixed**
# - Individual elements **cannot be modified** - immutable
# - Elements are accessed using a **zero-based index**
# - Elements do not have to be the same data type
# - You can also create a tuple using the built-in `tuple()` function

# %% [markdown]
# #### Define a tuple using round brackets `( )`

# %%
british_values = ('Democracy',
                  'Rule of law',
                  'Individual liberty',
                  'Mutual respect',
                  'Tolerance of those of different faiths and beliefs')

# %%
british_values

# %%
type(british_values)

# %%
len(british_values)

# %%
british_values[2]

# %% [markdown]
# ##### Tuples vs lists
#
# The key difference between tuples and lists is that `tuples` are immutable and `lists` are mutable. In practice, you can achieve the same functionality by using a `list`.

# %% [markdown]
# ## ☑️  Sets
#
# In Python a set is created by placing all the elements inside **curly braces { }**, separated by commas
#
# - All elements in a set are **unique** (no duplicates)
# - Elements are **not ordered or indexed**
# - A set can contain any number of elements with different data types (integer, float, string, bool)
# - It is also possible to use the `set()` function to make a set, this is useful when converting a `list` or `tuple` to a `set`
#
#
# #### Practical Use Cases of Python Sets
# Because sets cannot have multiple occurrences of the same element, sets are highly useful while removing duplicate values from a list or tuple.

# %% [markdown]
# #### Define a set using curly brackets `{ }`

# %%
friends = {'Ellie', 'Sarah', 'Amar', 'Sarah', 'Sarah', 'Sarah'}
friends

# %%
type(friends)

# %%
len(friends)

# %% [markdown]
# #### Python Set Methods
# - Python has a set of built-in methods that are available with every set object
#
# | Method | Description   |
# |:- |:- |
# |copy()|Returns a copy of the set|
# |discard()|Removes the specified item from the set|
# |update()|Update the set with the union of this set and others|

# %% [markdown]
# #### Some useful references:
#
# [Python Set Methods](https://docs.python.org/3/tutorial/datastructures.html#sets)
#
# [Python Set Methods](https://www.w3schools.com/python/python_ref_set.asp)

# %%
friends.update(['James', 'Ellie'])
friends

# %%
friends.discard('Sarah')
friends

# %%
sorted(friends, reverse=True)

# %% [markdown]
# Notice how the original **order is not retained**. Although here the items are displayed alphabetically, the order in which set items are stored in memory should be considered **arbitrary**.

# %%
required = ['F', 'A', 'C', 'B', 'A', 'C', 'A', 'D', 'H', 'B']   #define a list
required

# %%
set(required)

# %% [markdown]
#  - The built-in `set()` function is useful for identifying the **unique values** in a list

# %%
list(set(required))

# %%
sorted(list(set(required)), reverse=True)

# %% [markdown]
# - We can use the built-in `list()` function to return a list
# - As mentioned previously, the item order of a set is arbitary, but can be resolved using the built-in `sorted()` function

# %% [markdown]
# We can check for **membership** of a set as follows:

# %%
'Sarah' in friends

# %%
"Dan" in friends

# %% [markdown]
# The same `in` keyword can also be used to check for the **presence of a value** in a `list`:

# %%
rain = [6.5, 0, 0, 1.2, 2.6, 1.9, 5.4]
rain

# %%
6.5 in rain

# %%
0 in rain

# %% [markdown]
# ## ☑️  Combining Data Structures

# %% [markdown]
# We can also **combine data structures** in many ways:
# - Structures can be **nested** within one another with **no practical limit**

# %%
blog_post = { 'subject': 'How to live better',
              'user': {'name':'dave smith', 'email':'dave@email.com'},
              'tags': ('lifestyle', 'religion'),
              'likes':['Joe53ph', 'sara77', 'Cathy']
            }

# %%
blog_post['user']['email'] = 'dave@newemail.com'
blog_post

# %%
blog_post['likes'].append('Jonathan')
blog_post

# %% [markdown]
# - We can access the **object** in the dictionary using the **key**, and then perform operations on that object according to its **type**

# %% [markdown]
# <img src="data:image/png;base64,..."  width="200">
#
# Now open the following workbook: `data-structures-workbook.ipynb`
