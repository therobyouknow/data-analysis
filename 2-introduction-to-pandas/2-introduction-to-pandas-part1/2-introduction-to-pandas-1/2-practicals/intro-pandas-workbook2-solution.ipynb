# %% [markdown]
# ## Part 2: Importing, examining, and updating values in a dataset

# %% [markdown]
# **First, let's import Pandas**

# %%
import pandas as pd #Library for analysing and manipulating data

# %% [markdown]
# **Use the `.read_csv()` method to import the file `libraries.csv` from the `data` folder, assigning the result to `df`:**

# %%
df = pd.read_csv('data/libraries.csv')

# %% [markdown]
# **Q1) Check that the file has been imported as expected using the `.head()` method to look at the first `3` rows of `df`:**

# %%
#add you code below 
df.head(3)

# %% [markdown]
# **Q2) Use the `.shape` attribute to find out the number of rows and columns in `df`, assigning the number of rows to `rows` and number of columns to `cols`:**

# %%
#add you code below 
shape = df.shape
rows = shape[0]
cols = shape[1]

# %% [markdown]
# **We can check these using the `print` function**

# %%
#add you code below 
print(rows)
print(cols)

# %% [markdown]
# **Q3) Use the `.describe()` method on `df` to look at some statistics for the numerical data columns:**

# %%
#add you code below 
df.describe()

# %% [markdown]
# Notice that the value for `min` in both columns is negative, which suggests an error in the data.
#
# **Q4) You're told that there is an error in the row with index `2233`; use `.loc[]` to have a look at this row:**

# %%
#add you code below 
df.loc[2233]

# %% [markdown]
# **Q5) Using `.loc[]`, update the values for both `Weekly hours open` and `Weekly hours staffed` on this row to `57`:**

# %%
#add you code below 
df.loc[2233, ['Weekly hours open', 'Weekly hours staffed']] = 57

# %% [markdown]
# - Run your code again for the previous question to check that both values on the row at index `2233` have been updated.
#
# The `min` value for these columns (which can be seen again using the `.describe()` method on the DataFrame, or the `.min()` method on a given column), should now be `0`:

# %%
#add you code below 
df.loc[:, ['Weekly hours open','Weekly hours staffed']].min()

# %%
#add you code below 
df.loc[:, ['Weekly hours open','Weekly hours staffed']].describe()
