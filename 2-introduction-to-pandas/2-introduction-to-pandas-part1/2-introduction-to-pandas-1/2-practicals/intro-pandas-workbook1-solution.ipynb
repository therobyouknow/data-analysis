# %% [markdown]
# ## Part 1: Importing, examining, and updating values in a dataset

# %% [markdown]
# **First, let's import Pandas**

# %%
import pandas as pd #Library for analysing and manipulating data

# %%
df = pd.read_csv("data/diamonds.csv")

# %% [markdown]
# **Q1) Check that the file has been imported as expected using the `.head()` method to look at the first `3` rows of `df`:**

# %%
#add you code below 
df.head(3)

# %% [markdown]
# **Q2) Print out the columns**

# %%
# column names
#add you code below 
df.columns

# %% [markdown]
# **Q3) What does the data set look like in terms of dimensions?**

# %%
# shape
#add you code below 
df.shape

# %% [markdown]
# **Q4) Check the types of each column.**
#   1. What is the most common data type?
#   2. How many entries are there?
#   3. How much memory does this data set consume?

# %%
# column data types, number of entries and memory used
#add you code below 
# 1. float
df.info()
# 2. 
df.shape[0]
# 3. 4.1+ MB

# %% [markdown]
# **Q5) Examine the summary statistics of the data set.**

# %%
# summary stats
#add you code below 
df.describe()

# %%
df.describe(include='O')
