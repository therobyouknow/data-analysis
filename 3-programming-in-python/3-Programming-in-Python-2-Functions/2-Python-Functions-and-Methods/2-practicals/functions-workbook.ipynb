# %% [markdown]
# # Functions

# %% [markdown]
# **Q1) In the function `test_output` below:**
#
# - what are the parameters of the function?
# - how would you call the function with a = 3 and b = 4?
# - how many lines will be printed out, assuming that a = 3 and b = 4?
#
# **Write your answers in subsequent cell and then discuss with the tutor.**

# %%
def test_output(a, b):
    for i in range(b):
        print(a)

# %%
# Write your answers here

# %% [markdown]
# **Q2) Write a function, `sum_nos`, which takes as input (ie, parameters) 2 numbers and returns their sum.  Check that the returned value is correct by printing out the result for your choice of parameters.**
#
# **Practise changing the value of the parameters and re-checking that it still works.**

# %%
#add your code below
#def sum_nos(a, b):....

# %%
#check your code

print(sum_nos(5,6))  # Try other parameters

# %% [markdown]
# **Q3) Now Copy your code from above to the cell below and rename the function as `sum_mult`.  Then expand it so that it takes 3 numbers and multiplies the sum of the first 2 by the third. Again, print out the result and check that it works for a variety of inputs.**
#
# **When testing it's good to think about as wide a range of inputs as possible - it might seem unnecessary here, but it can get more complicated very easily. Check that the code still gives what you expect with negative numbers and zero(s).**

# %%
#add your code below
#def sum_mult(a, b, c):...

# %%
#below code should return 77

print(sum_mult(5, 6, 7))

# %% [markdown]
# **What do you think your code above would return if the first two parameters are not numbers but strings, while the third remains a number (assuming it is an integer). Try it and see if you get what you expect.**

# %%
print(sum_mult('a', 'b', 7))

# %% [markdown]
# **This illustrates that a user may try to use a function (indeed, any code!) in an unintended way. In this case, let's try to make sure that the user does not inadvertently use a string as any of the input numbers.**

# %% [markdown]
# **Q4) Copy your function `sum_mult` below and rename it `error_catching`. Write some additional code inside this new function so that if any of the parameters is a string, the function returns the string: 'Only numbers should be used. Please try again.'**
#
# **Hint: build up your code step by step. First, add code which only checks whether the first parameter is a string.  Once you have that working correctly, you can expand the code to include checks on the subsequent two variables. Also, recall that you can use type(`<variable>`) function to return the type of variable.**

# %%
#add your code below
#def error_catching(a, b, c):...

# %%
#check your code 

print(error_catching(5, 6, 'test'))

# %% [markdown]
# **Q5) Let’s explore another function which takes a list of numbers as its parameter and calculates the sum of the squares of the list. Using list `a` given below as a parameter, print the result.**

# %%
a = [2, 5, 3]

# %%
#add your code below
#def sq_list(list1):...

# %%
#check your code 

print(sq_list(a))

# %% [markdown]
# **Q6) Run the following code cell, which will load from the file `data.py` a list of 100 names.**

# %%
names_list = []
with open('data/data.txt') as f:
    names_list = [line.rstrip() for line in f]
names_list[:5]

# %% [markdown]
# **It's always a good idea to have a quick look at any data we have been provided with. Hence, in the cell below write 2 print statements: one which prints out the first 5 names in `names_list` and the other which prints out the last 5 names in `names_list`.**

# %%
#check the names in names_list

# %% [markdown]
# **Q7) Create a function called add_user with two parameters, called `users` and `name`, where `users` is a list and `name` is a string. The function should simply print out the first item of `users` and also print out `name` on separate lines. Test it with `names_list` as `users` and `Millie` as `name`.**

# %%
#add your code below
#def add_user(users, name):...

# %%
#test your code

add_user(names_list, 'Millie')

# %% [markdown]
# **Q8) Copy your code from above to the cell below, and amend it so that it does the following:**
#
# - `.append()` `name` to `users`
# - `print()` the message '`<name>` added successfully!'

# %%
#add your code below

# %% [markdown]
# **Check that the following code works as expected:**

# %%
#test your code

members = ['Helen', 'Sam']
add_user(members, 'John')
members

# %% [markdown]
# **Q9) Let’s Define a function called `unique` which takes a list and returns a `set()` of the unique values in that list**:
#
# - avoid using `list` as a parameter name, because it's already used by Python; give the parameter a different name, such as `user_list`
#
# **Note:** *Here and elsewhere in the notebook, by 'unique' we mean 'de-duplicated', rather than a count / list / set of the values which only occur once in the given object.*

# %%
#add your code below
#def unique(user_list):...

# %%
#test your code

unique(['Bill', 'Betty', 'Bill', 'Arthur', 'Mildred'])  # Try other lists as well

# %% [markdown]
# **Call `unique()` function using `names_list` and assign the returned value to `names_set`:**

# %%
names_set = unique(names_list)

# %%
print(names_set)

# %% [markdown]
# **Q10) Now we want to calculate how many values in a list are duplicated. Recall that len() will give the length of a list or set.**
#
# **Create a function called `duplicate_count` which should return the number of duplicate values in a list:**
#
# - call your `unique()` function within the `duplicate_count()` function
# - remember to avoid using a parameter name which has been used as a variable name elsewhere

# %%
#add your code below
#def duplicate_count(dupe_list):...

# %%
#test your code

duplicate_count(names_list)

# %% [markdown]
# **Q11) We are going to create a function called `names_dict`, which takes a list and returns a dictionary where:**
# - there is a `key` for each unique first character found in the list
# - the `values` are a list of the entries which begin with the character used for the `key`
# - the lists of entries are ordered alphabetically

# %% [markdown]
# **We will build up this function step-wise below. The below function takes a list of strings (eg, names) and returns a list of unique, first characters of those names, `keys`.  Test it using the list provided.**

# %%
#add your code below
#def names_dict(names):...

# %%
#run this code 

test_list = ['Alan', 'Ann', 'Christine', 'Jeffrey', 'Stewart', 'Simon', 'Robert', 'Ellie', 'Dorothy', 'Joanne', 'Jack']

# %%
list(names_dict(test_list))

# %% [markdown]
# **Q12) Copy your code for `names_dict` from above to the cell below and expand it, creating a dictionary where the keys are the letters in the list `keys`, and the values are lists of names that begin with that letter. Again, test your code using `test_list`.**

# %% [markdown]
# See below example of what the expected output should look like:
# <code>
#  {'R': ['Robert'],
#  'C': ['Christine'],
#  'S': ['Stewart', 'Simon'],
#  'E': ['Ellie'],
#  'D': ['Dorothy'],
#  'A': ['Alan', 'Ann'],
#  'J': ['Jeffrey', 'Joanne', 'Jack']}
# </code>

# %%
#add your code below
#def names_dict(names):...

# %%
#check your code please

names_dict(test_list)

# %% [markdown]
# **Q13) Copy your code for `names_dict` from above to the cell below and amend it so that each list of names is ordered alphabetically.**

# %%
#add your code below
#def names_dict(names):...

# %%
#have you checked your code?

names_dict(test_list)

# %% [markdown]
# **Assign to `all_names_dict` the value returned from calling `names_dict` with `names_list`:**

# %%
#add your code below

# %% [markdown]
# **Q14) Define a function called `unique_names_dict` which takes a list and returns a dictionary such as the one created above, but instead of lists the values are sets (of unique entries):**
# - Use the `names_dict` and `unique` functions previously defined in your solution
# - You may find the `.items()` dictionary method useful

# %%
#add your code below
#def unique_names_dict(names):...

# %%
#test code time 

unique_names_dict(names_list)

# %% [markdown]
# **Q15) Let’s explore the function `unique_count()` which takes a single character and a list, and returns the number of unique entries in the list which begin with that character:**
# - use the `unique_names_dict()` function defined above within `unique_count()`
# - if there are no matching items in the list, return `0` and print `None found`

# %%
#add your code below
#def unique_count(char, names):...

# %%
#tester

unique_count('J', names_list)

# %%
unique_count('I', names_list)
