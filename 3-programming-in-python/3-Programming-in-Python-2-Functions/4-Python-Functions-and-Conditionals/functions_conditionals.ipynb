# %% [markdown]
# # Assignment: Python Functions & Conditionals

# %% [markdown]
# ### Distance and speed conversions

# %% [markdown]
# **Q1.** You have been informed that `1` mile is equivalent to `1.61` kilometres.
#
# Based on the given facts create a function called `km` with a single parameter called `miles`, (which you can assume will always be a valid number) and returns the equivalent number of kilometres.
#
# - Hint: Use `1.61` value while making the conversion: `km = miles * 1.61`
#
# See below code syntax for some guidance:
# ```python
# def km(miles):
#     statement1
#     statement2
#     ...
#
#     return <results>
# ```

# %%
#add your code below
#def km(miles):
def km(miles):    
    km = miles * 1.61

    return km

# %% [markdown]
# Uncomment the following cell to see if your function works as expected:

# %%
km(85)

# %% [markdown]
# **Q2.** Use your `km` function as part of your working to calculate the total kilometres covered in the journeys in the list `journeys_miles` defined below. Assign the result to a variable called `journeys_km`:
#
# - Hint: Consider using a `for` loop to iterate through values in the list `journeys_miles`
# - Also make sure to create a counter to track the total kilometres
#
#
# See below code syntax for some guidance:
# ```python
# journeys_km = 0
#
# for entry in journeys_miles:
#     statement1
#     statement2
#     ...
#
# journeys_km
# ```

# %%
#add your code below
journeys_miles = [1.2, 5.3, 2.7, 8.2]

#journeys_km = ...


journeys_km = 0

for entry in journeys_miles:
    journeys_km += km(entry)

# %% [markdown]
# Once you have implemented the preceding code, uncomment the following cell to show the value of `journeys_km`:

# %%
journeys_km

# %% [markdown]
# **Q3.** Create a function called `over_kmph_limit` which takes two parameters:
# - `mph_speed`, representing the speed of a car in miles per hour
# - `kmph_limit`, representing the speed limit in kilometres per hour
#
# The function should return `True` if the car is exceeding the speed limit: `(mph_speed * 1.61) > kmph_limit`, and `False` otherwise.
#
# You can assume that the input values will always be single positive numerical values.
#
#
# See below code syntax for some guidance:
# ```python
#
# def over_kmph_limit(mph_speed, kmph_limit):
#
#     if <Conditional_statement>:
#         return True
#     else:
#         return False
# ```

# %%
#add your code below
#def over_kmph_limit(mph_speed, kmph_limit):

def over_kmph_limit(mph_speed, kmph_limit):

    if (mph_speed * 1.61) > kmph_limit:
        return True
    else:
        return False

# %% [markdown]
# Once you have implemented the function, uncomment the following cells and see if the statements evaluate as you expect:

# %%
over_kmph_limit(30, 40)

# %%
over_kmph_limit(30, 50)

# %% [markdown]
# **Q4.** There are 1000 metres in a kilometre and 3600 seconds in an hour.
#
# Based on the given facts create a function called `ms` which takes a single parameter called `kmph` (kilometre per hour), and returns the equivalent value in metres per second. You can use the following formula to carry out the conversion `(kmph/3600)*1000`.
#
# You can assume that any argument for `kmph` will be numerical, but if it is negative (i.e. `< 0`), you should instead return the string `'Please enter a positive value.'` Be sure that this string is formatted exactly as given here, i.e. including a full stop at the end.
#
# See below code syntax for some guidance:
# ```python
# def ms(kmph):
#     if kmph < 0:
#         return <result1>
#     else:
#         return <result2>
# ```

# %%
#add your code below
#def ms(kmph):
def ms(kmph):
    #There are 1000 metres in a kilometre and 3600 seconds in an hour.
    return (kmph/3600)*1000

# %% [markdown]
# Once you have implemented your `ms` function, you can uncomment the following cell and run it:

# %%
ms(156)

# %% [markdown]
# ### Finding entries based on criteria
#
# Make sure you run the following code cell to create the list `people` before you attempt any of the following questions

# %%
people = [('John', 36, 'M'),('Rachel', 24, 'F'),('Deardrie', 78, 'F'),('Ahmed', 17, 'M'),('Sienna', 14, 'F')]

people

# %% [markdown]
# **Q5.** Create a function called `adults` with a single parameter called `members`, which takes a list of tuples in the format given above (`name`, `age`, `gender`), and returns a list of names (the names only) of those who are aged 18 or over.
#
#
# - Hint: Consider using a `for` loop to iterate through values in the list
# - Use an `if condition` within the `for` loop to check for age values: 18 or over
# - Also make sure to create an `empty list` to append the people who are aged 18 or over
#
#
# See below code syntax for some guidance:
# ```python
# def adults(members):
#
#     <create_an_empty_list_to_append_the_filtered_data>
#
#     for entry in members:
#
#         if entry[1] >= 18:
#             statement1
#             statement2
#             ...
#
#
#     return <list_with_the_filtered_data>
# ```

# %%
#add your code below
#def adults(members):
def adults(members):
    names = []
    for entry in members:
        if entry[1] >= 18:
            names.append(entry[0])
    return names

# %% [markdown]
# Uncomment the following cell to see if the code above evaluates as you would expect:

# %%
adults(people)

# %% [markdown]
# **Q6.** Create a function called `average_age` which takes two parameters:
#
# - `members`, a list of tuples in the same format as `people` above
# - `gender`, a text string such as (but not limited to) `'M'` or `'F'`.
#
# It should return the average age of entries in `members` whose gender matches the argument given for `gender`.
#
# If no matches are found, return the string `'No matches found.'`
#
# As before, ensure this string is formatted exactly as given here.

# %%
#add your code below
#def average_age(members, gender):
def average_age(members, gender):
    cumulative_age = 0
    num_gender = 0
    for entry in members:
        if entry[2] == gender:
            cumulative_age = cumulative_age + entry[1]
            num_gender = num_gender + 1
    if num_gender > 0:
        average = cumulative_age / num_gender
    else:
        average = 'No matches found.'
    return average

# %% [markdown]
# Uncomment the following cells to see if your function works as expected:

# %%
average_age(people, 'M')

# %%
average_age(people, 'Z')

# %% [markdown]
# **Q7.** Create a function called `member_details`, with two parameters:
#
# - `entries`, a list of tuples, in the same format as the `people` list above
# - `name`, a string, representing the name of one of the entries
#
# The function should return a dictionary with two keys, `age` and `gender`, with the values being those from the tuple which contains the name passed as the second argument to the function. If the name isn't found in the list of tuples, return [`None`](https://www.w3schools.com/python/ref_keyword_none.asp).
#
#
#
# See below code syntax for some guidance:
# ```python
# def member_details(entries, name):
#
#     for entry in entries:
#
#         if entry[0] == name:
#             statement1
#             statement2
#             ...
#
#             return <a_dictionary_with_age_and_gender_info>
#
#     return None
# ```

# %%
#add your code below
#def member_details(entries, name):
def member_details(entries, name):
    for entry in entries:
        if entry[0] == name:
            details_dict = {
                "age": entry[1],
                "gender": entry[2]
            }
            return details_dict
    return None

# %% [markdown]
# Uncomment and run the following cells to call your `member_details` function using `people` and `'Ahmed'` as the arguments, and assign the result to `ahmed_details`.

# %%
ahmed_details = member_details(people, 'Ahmed')
ahmed_details

# %% [markdown]
# **Q8.** Create a function called `check_group` which has two arguments:
#
# - `members` a list of names representing existing members (just a list, not tuples as previously)
# - `group` a list of names representing visitors (who may or may not be members)
#
# The function should return a string in the `f-string` format `f'Member present: {person}.'` (ensure it matches this exactly), where `{person}` is replaced by the first name from the visitors list to be identified as a member.
#
# If no member is found, the function should return a string `'No members.'` (ensure it matches this exactly)
#
#
# See below code syntax for some guidance:
#
# ```python
# def check_group(members, group):
#
#     for person in group:
#         if person in members:
#             return <a_string>
#
#     return <a_string>
# ```

# %%
#add your code below
#def check_group(members, group):
def check_group(members, group):

    for person in group:
        if person in members:
            return f'Member present: {person}.'

    return 'No members.'

# %%
members = ['Alex', 'Danny', 'Kieran', 'Zoe', 'Caroline']
visitors = ['Scott', 'Helen', 'Raj', 'Danny']

# %% [markdown]
# See if your function works as expected by running the cell below:

# %%
check_group(members, visitors)
