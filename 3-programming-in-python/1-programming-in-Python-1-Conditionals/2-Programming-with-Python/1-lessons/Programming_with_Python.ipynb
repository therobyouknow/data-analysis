# %% [markdown]
# # Programming with Python

# %% [markdown]
# # Boolean operators
#
# We can use the following **operators** within **statements** containing Boolean (`True` or `False`) values:
#
# `and`: **both elements** must be `True` to produce a `True` result
# `or`: **at least one element** must be `True` to produce a `True` result
# `not`: **negates** the given result

# %% [markdown]
# <img src="data:image/png;base64,..." >

# %% [markdown]
# We also have the following operators for **comparing values**.
# The following can be used with objects of **any data type**:
#
# `==` equal to
# `!=` **not** equal to
#
# The following only work with **numeric** data types:
#
# `>` greater than
# `<` less than
#
# `>=` greater than or equal to
# `<=` less than or equal to

# %%
age=25
weight=90

print(age>10 and weight>80)   #True AND True  --> compound effect is True
print(age>10 and weight>100)  #True AND False --> compound effect is False
# Out:
# True
# False

# %%
age=25
weight=90

print(age>10 or weight>80)     #True OR True  --> compound effect is True
print(age>10 or weight>100)    #True OR False --> compound effect is True
# Out:
# True
# True

# %%
age=25

print(age>10) 
print(not age>10)              #Reverse the result, returns False if the result is True
# Out:
# True
# False

# %% [markdown]
# ## Boolean expressions

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %% [markdown]
# - `bool(0)` is considered `False` but other non-zero numbers evaluate to `True`

# %%
26 == 26.0
# Out:
# True

# %% [markdown]
# - an `int` can be equal to a `float` if the values are considered the same

# %%
'42' == 42
# Out:
# False

# %% [markdown]
# - a `string` will never be considered equal to a `float` or `int`

# %%
'python' == 'Python'
# Out:
# False

# %% [markdown]
# - comparison of strings is case-sensitive

# %%
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %% [markdown]
# - strings are considered `True`, empty strings are considered `False`

# %% [markdown]
# The [documentation](https://docs.python.org/2/library/stdtypes.html#truth-value-testing) provides a list of values considered to be `False`, which is essentially:
#
# - numeric values which equal **zero**
# - **empty** sequences and data structures
# - `None` and (of course) `False` values

# %% [markdown]
# # Conditional expressions
#
# Conditional expressions are used when we want the execution of parts of our code to be dependent on whether a condition evaluates to `True` or `False`.
#
# ### `if` statements

# %%
age = 17

if age < 18:
    print('Child')

# %% [markdown]
# ### `if` statements
#
# - the statement begins with the `if` keyword
# - this is followed by a **boolean expression** (the condition)
# - the line ends with a colon `:`
# - the code to be exectued if the condition is met (i.e. `True`) is **indented** on the following line(s)

# %% [markdown]
# ### `else` statements

# %%
age = 17

if age < 18:
    print('Child')

else:
    print('Adult')

# %% [markdown]
# ### `else` statements
# - the **indentation** and use of a **colon** are the same as for the `if` statement
# - no value of `age` can result in both `print()` statements being executed

# %% [markdown]
# ### `elif` statements

# %%
age = 77

if age < 18:    
    category = 'Child'

elif age >= 65:    
    category = 'Pensioner'
    
else:
    category = 'Adult'
    
print(category)

# %% [markdown]
# ### `elif` statements
#
# The `elif` keyword allows us to specify further conditions to be evaluated after an `if` statement:

# %% [markdown]
# Notice how the `print()` statement is after i.e. *outside* the conditional expression.

# %% [markdown]
# Python will evaluate each condition in turn and execute the first (and only the first) one which evaluates to `True`.
#
# - The `elif` and `else` statements are **optional**
# - We can have numerous `elif` statements
#
#
#
# If no conditions are matched and there is no `else` statement, Python will move on and continue to evaluate the subsequent code.

# %%
category = None
age = 64

if age < 0 or age > 150:    
    print('Invalid age entered')

elif age >= 65:    
    category = 'Pensioner'

elif age >= 18:    
    category = 'Adult'
    
else:
    category = 'Child'
    
print(category)
# Out:
# Adult

# %% [markdown]
# - We can evaluate multiple conditions together using `or`, `and`, `not`
# - The **indented code blocks** are only executed when the condition is `True`
# - Any code before or after the conditional expressions is executed as normal

# %% [markdown]
# ## Demo
#
# The `input` function reads a line from the input (usually from the user), converts the line into a string by removing the trailing newline, and returns it. `input` is used to ask the user of the program (not the programmer) a question, and then wait for a typed response.
#
# The `eval` function evaluates the string expression and returns its value. For example, Eval("1 + 1") returns 2.

# %%
weight = eval(input('How many kilograms does your suitcase weigh? '))

if weight > 23:
    print('There is a £25 charge for luggage that heavy.')
print('Thank you for this service.')
# Out:
# How many kilograms does your suitcase weigh? 12
# Thank you for this service.

# %%
# check returned data type if not using eval

type(input('How many kilograms does your suitcase weigh? '))
# Out:
# How many kilograms does your suitcase weigh? 15
# str

# %%
# check returned data type if using eval

type(eval(input('How many kilograms does your suitcase weigh? ')))
# Out:
# How many kilograms does your suitcase weigh? 27
# int

# %%
# another example for using eval

x = 2
y = 3
eval('x+3*y')
# Out:
# 11

# %%
type(weight)
# Out:
# int

# %% [markdown]
# # Loops
#
# A **loop** is a **sequence of instructions** that is **repeated** until a **condition** is met.
#
# - Computers can perform repetitive operations very quickly
# - 'Don't Repeat Yourself' (**DRY**) principle when writing code
#
#
# Each time the code within a loop is executed is considered an **iteration**.

# %% [markdown]
# ### Syntax
#
# The general syntax for a **for loop** is indicated below:
#
# ```python
#     for iterator_name in iterating_sequence:
#         …statements…
# ```
#
# This is a for loop. It has the heading starting with `for`, followed by a
# variable name (count in this case), the word `in`, some sequence, and a final colon.
# As with function definitions and other heading lines, the colon at the end of
# the line indicates that a consistently indented block of statements follows
# to complete the for loop.

# %% [markdown]
# ### `for` loops

# %% [markdown]
# <img src="data:image/png;base64,..." >

# %% [markdown]
# ### `for` loops
#
# `for` loops execute code **for each item** in a sequence (such as a list of values):

# %%
names = ['Dave', 'Sara', 'Mo']

for name in names:
    print(name)

# %% [markdown]
# ```python
# for name in names:
#     print(name)
# ```
#
# - The `for` loop performs the operation *for* each value in the `names` list
# - We can use any string between `for` and `in`; this simply determines how we refer to each value in the subsequent code

# %% [markdown]
# ## simple examples

# %%
for count in [1, 2, 3]:
    print(count)
    print('Yes' * count)
# Out:
# 1
# Yes
# 2
# YesYes
# 3
# YesYesYes

# %%
for i in range(10):
    print('Hello')
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
word = 'computer'
for letter in word:
    print(letter)
# Out:
# c
# o
# m
# p
# u
# t
# e
# r

# %%
teas = ['earl grey', 'darjeeling', 'english breakfast', 'lapsang souchong', 
        'oolong', 'kombucha', 'green tea']

for tea in teas:
    print(tea)
# Out:
# earl grey
# darjeeling
# english breakfast
# lapsang souchong
# oolong
# kombucha
# green tea

# %%
for tea in teas:
    print(tea[0])
# Out:
# e
# d
# e
# l
# o
# k
# g

# %% [markdown]
# ### `for` loops

# %%
profiles = [('John', 46), ('Paul', 21), ('Jasmine', 26)]
ages = []

for entry in profiles:
    ages.append(entry[1])

print(ages)
print(f'Average age is {sum(ages) / len(ages)}')
# Out:
# [46, 21, 26]
# Average age is 31.0

# %% [markdown]
# - We have used a `for` loop to **iterate** over a list of tuples
# - Our `profiles` list could have any number of entries

# %% [markdown]
# ### `for` loops

# %%
bill = 0
freebies = 0
prices = [4.75, 14, 4, 0, 18.50, 1.25, 5.60, 0]

for item_price in prices:
    
    if item_price == 0:
        freebies = freebies+1
        
    bill = bill+item_price    
    
print(f'Total is £{bill}, including {freebies} free items!')
# Out:
# Total is £48.1, including 2 free items!

# %% [markdown]
# - We can **nest** conditional statements within loops
# - Variables can be modified and then used outside the loop

# %%
shopping_list = ['milk', 'bread', 'yoghurt', 'pizza', 'pasta']

for item in shopping_list:
    
    if item == 'pizza':
        for person in ['Joe', 'Paula']:
            print(item + ' for ' + person)
    
    else:
        print(item)
# Out:
# milk
# bread
# yoghurt
# pizza for Joe
# pizza for Paula
# pasta

# %% [markdown]
# ### Additonal for loop resources
# - [for loops at cyberciti](http://www.cyberciti.biz/faq/python-for-loop-examples-statements/)
# - [for loops at python for beginners](http://www.pythonforbeginners.com/control-flow-2/python-for-and-while-loops)
# - [for loops at python handson](http://anh.cs.luc.edu/python/hands-on/3.1/handsonHtml/loops.html)

# %% [markdown]
# <img src="data:image/png;base64,..."   width=100 height=100 />
#
# ---
#
# Finish the questions 1-4: `for-and-while-loop-workbook.ipynb`

# %% [markdown]
# ### `while` loops
#
# <img src="data:image/png;base64,..." >

# %% [markdown]
# ### Syntax
#
# The general syntax for a **while loop** is indicated below:
#
# ```python
#     while condition:
#         …statements…
# ```
#
# The syntax includes the following parts:
# * in the first line
#     * the keyword **`while`**
#     * followed by a condition which evaluates to `true` or `false`
#     * followed by a colon
# * an indented code block including all statements to be executed if the condition evaluates to true

# %% [markdown]
# ### `while` loops

# %%
count = 0
while count < 5:
    print(count)
    count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 0
while a < 5:
    a += 1
    print(a)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### `while` loops
# `while` loops continually execute **while** a **conditional expression** is `True`

# %%
units = 'kg'
weight = 80
target = 72
monthly_change = -3
month = 0

while weight > target:
    month = month+1
    weight = weight+monthly_change
    print(f'Month {month}: {weight}')

print(f'It will take {month} months to reach {target}{units}.')
# Out:
# Month 1: 77
# Month 2: 74
# Month 3: 71
# It will take 3 months to reach 72kg.

# %% [markdown]
# - Decrease the value of weight by 3 units, until weight is above 72

# %% [markdown]
# ### `while` loops
#
# - Make sure that the loop will stop eventually, i.e. that the condition will become `False`
#     - a loop which never stops is known as an **infinite loop**
#
# - You are likely to use `for` loops more frequently in data analysis
#     - `while` loops are more often found in **continuous processes**, for example as a means to shut off a machine if a safety alert is triggered

# %%
# Fun example, to un comment block press CMD + / 

# reply = None
# while reply != 'stop':
#     reply = input('Enter text, [type "stop" to quit]: ')
#     reply = reply.lower()
#     print(reply)

# %% [markdown]
# ### Additional resources
#
# - [for and while loops at python for beginners](http://www.pythonforbeginners.com/control-flow-2/python-for-and-while-loops)
# - [for loops at cyberciti](http://www.cyberciti.biz/faq/python-for-loop-examples-statements/)
# - [for loops at python hands-on](http://anh.cs.luc.edu/python/hands-on/3.1/handsonHtml/loops.html)
# - [while loops at learn python the hard way](http://learnpythonthehardway.org/book/ex33.html)

# %% [markdown]
# <img src="data:image/png;base64,..."   width=100 height=100 />
#
# ---
#
# Finish the questions 5-7: `for-and-while-loop-workbook.ipynb`
#
#
# Now open the following workbook: `conditionals-loops-workbook.ipynb`
