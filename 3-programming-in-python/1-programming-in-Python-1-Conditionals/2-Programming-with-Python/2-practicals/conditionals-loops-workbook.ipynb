# %% [markdown]
# # Conditional expressions

# %% [markdown]
# **Run the following code cell to create `age` and `min_age` variables. These will be referenced during following questions.**

# %%
age = 10
min_age = 18

print(age)
print(min_age)

# %% [markdown]
# **Q1) Write an expression that prints 'You are not allowed in' if `age < min_age`:**

# %%
#add your code below

# %% [markdown]
# **Q2) Copy your code from above to the cell below, then do the following:**
#
# - add a second `print()` statement to be executed if `age < min_age`, which uses string formatting to print **'Come back in `<x>` years'**, where `<x>` is the difference between `min_age` and `age`.
# - you can make use of `f-strings` and the `.format()` method for this activity

# %%
#add your code below

# %% [markdown]
# **Run the cell below to assign 'Dave' to the variable `name`**

# %%
name = 'Dave'
name

# %% [markdown]
# **Q3) Copy your code from above to the cell below, then do the following:**
# - add an `else` statement, such that **'Welcome, `<name>`**' is printed if `age >= min_age`
# - you can make use of `f-strings` and the `.format()` method for this activity

# %%
#add your code below

# %% [markdown]
# ## Iteration - for loops

# %% [markdown]
# **Run the following code cell to create `ages`, `names` and `details` variables. These will be referenced during following questions**

# %%
ages = [17, 22, 14, 55, 23, 19, 16, 21, 33, 42, 25]
names = ['John', 'Mandy', 'Siri', 'Robert', 'Saul', 'Paulina', 'Fay', 'Mahmood', 'Ben', 'Angela', 'Vicky']
details = list(zip(names, ages))

# %% [markdown]
# You don't need to worry about understanding the code above. The outcome is three variables:
#
# - `ages`: a list of ages
# - `names`: a list of names. Each of the people's names have their ages shown in `ages`, and in the same order.
# - `details`: a list of tuples, as can be seen by running the cell below:

# %%
details

# %% [markdown]
# **Q4) First, we will count the number of `ages` present.**
# - Create a counter, say variable `counter`, and set its value to `0`
# - Then use a `for` loop to iterate through the list `ages`, incrementing `counter` on each loop by `1`
# - At the end, `print` the statement **'The number of ages in the list is `<your result>`**, where `<your result>` is the new value of `counter`
# - you can make use of `f-strings` and the `.format()` method for this activity

# %%
#add your code below

# %% [markdown]
# **Q5) Secondly, we will count the number of `names` present.**
# - Create a counter, say variable `counter_names`, and set its value to `0`
# - Then use a `for` loop to iterate through the list `names`, incrementing `counter_names` on each loop by `1`
# - At the end, `print` the statement **'The number of names in the list is `<your result>`**, where `<your result>` is the new value of `counter_names`
# - you can make use of `f-strings` and the `.format()` method for this activity

# %%
#add your code below

# %% [markdown]
# **Now, let's explore `if/elif/else` statements that compare the number of ages and the number of names**
#
# - If the two values are the same the code should produce **'There are the same number of ages and names'**
# - otherwise it should produce **'There are fewer ages than names'** or **'There are fewer names than ages'**, depending on which is the case

# %%
#add your code below

# %% [markdown]
# **For this task, let's use a `for` loop to iterate through each tuple in `details`**
# - Where the `age` value in tuple is less than `min_age`, print **'`<name>` is too young'**
# - `<name>` is the `name` value appearing in the tuple

# %%
details

# %%
#add your code below

# %% [markdown]
# **Q6) Copy your code from above into the cell below.**
#
# - Create a variable, `number`, before the `for` loop and set its value to `0`
# - Next, add a further statement to the `for` loop to count the number of people who are not too young (this is captured by the variable `number`)
# - `print` a final statement **'The number of people who can attend is `<number>`'**
# - you can make use of `f-strings` and the `.format()` method for this activity

# %%
#add your code below

# %% [markdown]
# **Q7) It would be more convenient to print out a single list of those who are too young, and those who aren't.**
#
# - Create two empty lists called `refused` and `inside` respectively.
# - Then loop through `details` and use `.append()` to add the person's `name` to `refused` list if they are too young, and to `inside` list otherwise. (See the Introduction to Python lessons if you want to refresh your memory of `.append()`)
# - `Print` out both lists

# %%
#add your code below

# %% [markdown]
# **Now let's use the `len()` function to calculate the number of people in the  `inside` list and display the results as '`<your answer>` people are inside':**
# - see the Introduction to Python lessons if you want to refresh your memory on len() function

# %%
#add your code below

# %% [markdown]
# **Q8) Now calculate the percentage of all people who are in `inside` list. `Print` the statement 'x% of people are inside'.**
# - you can make use of `f-strings` and the `.format()` method for this activity

# %%
#add your code below

# %% [markdown]
# As you can see, it doesn't look very reader-friendly!
#
# **Q9) Use `round()` function to print out the result again, but only to one decimal place.**
# - see the Introduction to Python lessons if you want to refresh your memory on round() function

# %%
#add your code below

# %% [markdown]
# **Q10) Run the cell below.**
#
# - It sets the capacity of a venue, `capacity` to the value 5, and creates an empty list, `reserves`, for those who are eligible, ie, over `min_age`, but for whom there is not enough room.

# %%
capacity = 5
reserves = []

# %% [markdown]
# **Copy your code from Question7 and update it so that:**
# - if the `age` is `>= min_age` but `len(inside) >= capacity`, then `.append()` the `name` to the `reserves` list, otherwise `.append()` the `name` to the `inside` list.
# - if they are too young: `age` is `< min_age` use `.append()` to add the person's `name` to `refused` list
# - Print out all three lists, ie, `inside`, `reserves` and `refused`.

# %% [markdown]
# **use the structure below as a guide while formulating your answer**
# <code>
#
#     for <statement>:
#         if <statement>:
#             if <statement>:
#                 .....
#             else:
#                 .....
#         else:
#             .....
# </code>

# %%
#add your code below
